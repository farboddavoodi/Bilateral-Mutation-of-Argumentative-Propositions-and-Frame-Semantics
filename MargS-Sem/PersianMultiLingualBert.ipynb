# %%
# %%capture
# !pip install --upgrade transformers

# %%
# %%capture
# !pip install datasets

# %%
# %%capture
# !pip install accelerate -U

# %%
# %%capture
# !pip install evaluate

# %%
# %%capture
# !pip install seqeval

# %%
# %%capture
# !pip install scikit-learn

# %%
# %%capture
# !pip install matplotlib

# %%
# %%capture
# !pip install sklearn

# %%
from google.colab import drive
import torch
import pandas as pd
import evaluate
import matplotlib.pyplot as plt
import os
import numpy as np
from sklearn.model_selection import train_test_split
from tokenizers import Encoding
from collections import defaultdict
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertForTokenClassification, AdamW, get_linear_schedule_with_warmup, Trainer, TrainingArguments,  BatchEncoding

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device("cuda")
json_data = '/content/drive/MyDrive/davodi.json'
df = pd.read_json(json_data)
df = df.drop(['_id', 'sentence', 'frame', 'lexicalUnit', 'status', 'issuer', 'is_active', 'createdAt', 'updatedAt', 'PId', 'lang', 'description', 'lexicalUnitHint', 'reviewer', 'lexicalUnitHelper', 'frameHelper', 'frameName', 'lexicalUnitName'], axis = 1)

# %%
def framenet_tags(FN_tags):
    framenet_pattern = []
    for FN_tag in FN_tags:
        tag_type = FN_tag.get('tagType')
        if tag_type == 5:
            element = FN_tag.get('element', {})
            element_name = element.get('name', '')
            framenet_pattern.append(element_name)
        else:
            framenet_pattern.append('O')
    return framenet_pattern

# %%
df['frameNetTags'] = df['frameNetTags'].apply(lambda FN_tags : framenet_tags(FN_tags))

# %%
df
# Out:
#                                                    words  \
# 0      خانم نزهت‌الدوله گرچه تا به حال سه تا شوهر کرد...
# 1      خانم نزهت‌الدوله گرچه تا به حال سه تا شوهر کرد...
# 2                     تو به من مجال دادی تا پروانه شوم .
# 3                     تو به من مجال دادی تا پروانه شوم .
# 4      هر زمان این غریزه و فطرت و رشد سنی و عقلی و اج...
# ...                                                  ...
# 32724  روسیه به زودی برای عمل به تعهدهای خود به اروپا...
# 32725  منازعه و مشاجرۀ پدر و مادر اقدام ناخوشایندی اس...
# 32726  منازعه و مشاجرۀ پدر و مادر اقدام ناخوشایندی اس...
# 32727  منازعه و مشاجرۀ پدر و مادر اقدام ناخوشایندی اس...
# 32728  منازعه و مشاجرۀ پدر و مادر اقدام ناخوشایندی اس...
#
#                                             frameNetTags  \
# 0      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 1      [جستجو_کننده, جستجو_کننده, O, O, O, O, O, O, O...
# 2      [مرجع_ذیصلاح, قهرمان, قهرمان, O, O, عمل, عمل, ...
# 3                   [O, O, O, O, O, O, دسته_نهایی, O, O]
# 4      [O, O, موجودیت, موجودیت, موجودیت, موجودیت, موج...
# ...                                                  ...
# 32724  [بحث‌کنندگان, زمان, زمان, مسئله, مسئله, مسئله,...
# 32725  [O, O, O, بحث‌کنندگان, بحث‌کنندگان, بحث‌کنندگا...
# 32726  [روش, روش, روش, عامل, عامل, عامل, O, توضیح, O,...
# 32727  [O, O, O, O, O, O, O, O, O, O, شاخص, شاخص, O, ...
# 32728  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
#
#                                             propBankTags
# 0      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 1      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 2            [B-A0, B-A2, O, B-NVE, B-V, B-PRP, O, O, O]
# 3                       [O, O, O, O, O, O, B-A2, B-V, O]
# 4      [O, O, O, B-A2, O, O, O, O, O, O, O, O, O, B-N...
# ...                                                  ...
# 32724  [B-A0, B-TMP, O, B-A2, O, O, O, O, O, O, O, O,...
# 32725  [B-N-V, O, O, B-A0, B-A1, O, O, O, O, O, O, O,...
# 32726  [B-A1, O, O, O, O, O, B-A2, O, B-V, O, O, O, O...
# 32727  [O, O, O, O, O, O, O, O, O, O, B-Arg2_B1, O, B...
# 32728  [O, O, O, O, O, O, O, O, O, O, O, O, O, B-N-V,...
#
# [32729 rows x 3 columns]

# %%
train_data, temp_data = train_test_split(df, test_size=0.2, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42)
print("Training set size:", len(train_data))
print("Validation set size:", len(validation_data))
print("Test set size:", len(test_data))

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
tokenizer = AutoTokenizer.from_pretrained("bert-base-multilingual-uncased")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.72M [00:00<?, ?B/s]

# %%
df["Words"] = df["words"].apply(lambda sentence: [word.strip() for word in sentence.split(' ')])
# Out:
# <ipython-input-21-ce01e66bb15d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Words"] = df["words"].apply(lambda sentence: [word.strip() for word in sentence.split(' ')])

# %%
df["Words"]
# Out:
# 0     [خانم, نزهت‌الدوله, گرچه, تا, به, حال, سه, تا,...
# 1     [خانم, نزهت‌الدوله, گرچه, تا, به, حال, سه, تا,...
# 2          [تو, به, من, مجال, دادی, تا, پروانه, شوم, .]
# 3          [تو, به, من, مجال, دادی, تا, پروانه, شوم, .]
# 4     [هر, زمان, این, غریزه, و, فطرت, و, رشد, سنی, و...
#                             ...
# 95    [یکی, از, ضعف‌های, اصلی, در, نمایش, زایشی, ،, ...
# 96    [از, نحوۀ, نشستن, ،, ایستادن, ،, استفاده, از, ...
# 97    [سعی, کنید, چند, نمونه, از, این, حرکات, را, ات...
# 98    [سعی, کنید, چند, نمونه, از, این, حرکات, را, ات...
# 99    [پس, از, عادت, کردن, کامل, به, این, چند, حرکت,...
# Name: Words, Length: 100, dtype: object

# %%
df
# Out:
#                                                 words  \
# 0   خانم نزهت‌الدوله گرچه تا به حال سه تا شوهر کرد...
# 1   خانم نزهت‌الدوله گرچه تا به حال سه تا شوهر کرد...
# 2                  تو به من مجال دادی تا پروانه شوم .
# 3                  تو به من مجال دادی تا پروانه شوم .
# 4   هر زمان این غریزه و فطرت و رشد سنی و عقلی و اج...
# ..                                                ...
# 95  یکی از ضعف‌های اصلی در نمایش زایشی ، عدم توانا...
# 96  از نحوۀ نشستن ، ایستادن ، استفاده از دست‌ها و ...
# 97  سعی کنید چند نمونه از این حرکات را اتخاذ کرده ...
# 98  سعی کنید چند نمونه از این حرکات را اتخاذ کرده ...
# 99  پس از عادت کردن کامل به این چند حرکت ، چند رفت...
#
#                                          frameNetTags  \
# 0   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 1   [جستجو_کننده, جستجو_کننده, O, O, O, O, O, O, O...
# 2   [مرجع_ذیصلاح, قهرمان, قهرمان, O, O, عمل, عمل, ...
# 3                [O, O, O, O, O, O, دسته_نهایی, O, O]
# 4   [O, O, موجودیت, موجودیت, موجودیت, موجودیت, موج...
# ..                                                ...
# 95  [O, O, O, O, O, O, O, O, O, O, رویداد, رویداد,...
# 96  [O, O, O, O, O, O, O, ابزار, ابزار, ابزار, ابز...
# 97  [O, O, هدف, هدف, هدف, هدف, هدف, هدف, هدف, هدف,...
# 98  [O, O, O, O, O, O, O, O, O, O, O, مدت_زمان, مد...
# 99  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
#
#                                          propBankTags  \
# 0   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 1   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 2         [B-A0, B-A2, O, B-NVE, B-V, B-PRP, O, O, O]
# 3                    [O, O, O, O, O, O, B-A2, B-V, O]
# 4   [O, O, O, B-A2, O, O, O, O, O, O, O, O, O, B-N...
# ..                                                ...
# 95  [O, O, O, O, O, O, O, O, O, B-N-V, B-A1, O, O,...
# 96  [O, O, O, O, O, O, B-N-V, B-A1, O, O, O, O, O,...
# 97  [B-NVE, B-V, O, O, O, O, O, O, O, O, O, O, O, ...
# 98  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-E...
# 99  [O, O, O, O, O, O, O, O, O, O, B-EXT, B-N-V, O...
#
#                                                 Words
# 0   [خانم, نزهت‌الدوله, گرچه, تا, به, حال, سه, تا,...
# 1   [خانم, نزهت‌الدوله, گرچه, تا, به, حال, سه, تا,...
# 2        [تو, به, من, مجال, دادی, تا, پروانه, شوم, .]
# 3        [تو, به, من, مجال, دادی, تا, پروانه, شوم, .]
# 4   [هر, زمان, این, غریزه, و, فطرت, و, رشد, سنی, و...
# ..                                                ...
# 95  [یکی, از, ضعف‌های, اصلی, در, نمایش, زایشی, ،, ...
# 96  [از, نحوۀ, نشستن, ،, ایستادن, ،, استفاده, از, ...
# 97  [سعی, کنید, چند, نمونه, از, این, حرکات, را, ات...
# 98  [سعی, کنید, چند, نمونه, از, این, حرکات, را, ات...
# 99  [پس, از, عادت, کردن, کامل, به, این, چند, حرکت,...
#
# [100 rows x 4 columns]

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-multilingual-uncased")

# %%
tokenized_input = tokenizer(df['words'][0].split(' '), is_split_into_words=True)
tokenizer.convert_ids_to_tokens(tokenized_input["input_ids"])
# Out:
# ['[CLS]',
#  'خان',
#  '##م',
#  'ن',
#  '##زه',
#  '##تال',
#  '##دو',
#  '##له',
#  'گ',
#  '##ر',
#  '##چه',
#  'تا',
#  'به',
#  'حال',
#  'سه',
#  'تا',
#  'ش',
#  '##وه',
#  '##ر',
#  'کرده',
#  'و',
#  'شش',
#  'بار',
#  'ز',
#  '##ایی',
#  '##ده',
#  'و',
#  'دو',
#  'تا',
#  'از',
#  'دختر',
#  '##های',
#  '##ش',
#  'هم',
#  'به',
#  'خان',
#  '##ە',
#  'دا',
#  '##ماد',
#  'ف',
#  '##رس',
#  '##تاد',
#  '##ه',
#  '_',
#  'شدهاند',
#  'و',
#  'حال',
#  '##ا',
#  'دیگر',
#  'برای',
#  'خودش',
#  'مادر',
#  '##ب',
#  '##زر',
#  '##گ',
#  'شده',
#  '_',
#  'است',
#  '،',
#  'باز',
#  'هم',
#  'ع',
#  '##قی',
#  '##ده',
#  'دارد',
#  'که',
#  'پی',
#  '##ری',
#  'و',
#  'جوان',
#  '##ی',
#  'دست',
#  'خود',
#  'اد',
#  '##م',
#  'است',
#  'و',
#  'گ',
#  '##ر',
#  '##چه',
#  'سر',
#  'و',
#  'هم',
#  '##سر',
#  'و',
#  'خ',
#  '##ویش',
#  '##ان',
#  'و',
#  'دوست',
#  '##ان',
#  'می',
#  '##گو',
#  '##یند',
#  'که',
#  'پنج',
#  '##اه',
#  'سال',
#  '##ی',
#  'دارد',
#  'ولی',
#  'هنوز',
#  'دو',
#  'دست',
#  '##ی',
#  'به',
#  'جوان',
#  '##یا',
#  '##ش',
#  'چ',
#  '##سب',
#  '##ید',
#  '##ه',
#  'و',
#  'هنوز',
#  'هم',
#  'در',
#  'جس',
#  '##تج',
#  '##وی',
#  'ش',
#  '##وه',
#  '##ر',
#  'ای',
#  '##دها',
#  '##ل',
#  'به',
#  'این',
#  'در',
#  'و',
#  'ان',
#  'در',
#  'می',
#  '##زند',
#  '.',
#  '[SEP]']

# %%
def create_role_id_dictionary():
    """Creates a dictionary that maps PropBank roles to numerical IDs."""
    #roles = set()
    frame_elements = set()
    for _, row in df.iterrows():
        prop_str = row['propBankTags']
        framenet_str = row['frameNetTags']
     #   roles.update(prop_str)
        frame_elements.update(framenet_str)
    #role_id_dict = defaultdict(int)
    frame_id_dict = defaultdict(int)
    index = 1
    #for role in roles:
    #    role_id_dict[role] = index
    #    index += 1
    for frame_element in frame_elements:
        frame_id_dict[frame_element] = index
        index += 1
    return frame_id_dict, frame_elements

# %%
frame2id, frame_elements = create_role_id_dictionary()
print("Frame2ID:" + str(frame2id))
print("Frame Elements:" + str(frame_elements))
# Out:
# Frame2ID:defaultdict(<class 'int'>, {'موجودیت_جستجوشده': 1, 'رویداد': 2, 'مورد_2': 3, 'الزام': 4, 'مجری2': 5, 'مورد': 6, 'پذیرنده': 7, 'مسیر': 8, 'توصیف_گر': 9, 'محصول': 10, 'توصیف\u200cنما': 11, 'دسته_نهایی': 12, 'هدف_ذاتی': 13, 'کنش\u200cپذیر': 14, 'قهرمان': 15, 'مدت': 16, 'عقیده': 17, 'متن': 18, 'پدیده': 19, 'تجربه\u200cگر': 20, 'پرداخت_کننده': 21, 'دامنه': 22, 'تاثیر': 23, 'علت': 24, 'عامل': 25, 'بسامد': 26, 'اصل_و_نسب': 27, 'رقابت': 28, 'محدوده': 29, 'مجری1': 30, 'توزیع\u200cکننده': 31, 'موجودیت_خلق_شده': 32, 'شمارش': 33, 'کالا': 34, 'O': 35, 'توصیف': 36, 'مقصد': 37, 'گیرنده': 38, 'پارامتر': 39, 'وسیله': 40, 'شریک_اول': 41, 'زمان': 42, 'کاربرد': 43, 'وضعیت_نهایی': 44, 'عمل': 45, 'كنش_پذیر': 46, 'برگزیده': 47, 'ابزار': 48, 'مبدأ': 49, 'موجودیت': 50, 'نام': 51, 'توصیفگر': 52, 'کنش': 53, 'فرستنده': 54, 'مورد_1': 55, 'تشخیص\u200cگر': 56, 'توصیفی': 57, 'شخص': 58, 'مالکیت': 59, 'رویداد_پیش\u200cزمینه': 60, 'گوینده': 61, 'رویداد_مقایسه': 62, 'مقوله': 63, 'مدت_زمان': 64, 'محل': 65, 'فعالیت': 66, 'جریمه': 67, 'بارش': 68, 'مکان': 69, 'مسافر': 70, 'محل_اجرا': 71, 'جستجو_کننده': 72, 'کیفیت_نهایی': 73, 'کنشگر': 74, 'موجود': 75, 'توصیف\u200cگر': 76, 'محتوا': 77, 'پیکر': 78, 'حسگر': 79, 'اهداکننده': 80, 'موضوع': 81, 'مالک': 82, 'شیوه': 83, 'هدف': 84, 'مرجع_ذیصلاح': 85, 'طرف_متأثر': 86, 'مقصود': 87, 'پیام': 88, 'هدف_رویداد': 89, 'درجه': 90, 'رویداد_همزمان': 91})
# Frame Elements:{'موجودیت_جستجوشده', 'رویداد', 'مورد_2', 'الزام', 'مجری2', 'مورد', 'پذیرنده', 'مسیر', 'توصیف_گر', 'محصول', 'توصیف\u200cنما', 'دسته_نهایی', 'هدف_ذاتی', 'کنش\u200cپذیر', 'قهرمان', 'مدت', 'عقیده', 'متن', 'پدیده', 'تجربه\u200cگر', 'پرداخت_کننده', 'دامنه', 'تاثیر', 'علت', 'عامل', 'بسامد', 'اصل_و_نسب', 'رقابت', 'محدوده', 'مجری1', 'توزیع\u200cکننده', 'موجودیت_خلق_شده', 'شمارش', 'کالا', 'O', 'توصیف', 'مقصد', 'گیرنده', 'پارامتر', 'وسیله', 'شریک_اول', 'زمان', 'کاربرد', 'وضعیت_نهایی', 'عمل', 'كنش_پذیر', 'برگزیده', 'ابزار', 'مبدأ', 'موجودیت', 'نام', 'توصیفگر', 'کنش', 'فرستنده', 'مورد_1', 'تشخیص\u200cگر', 'توصیفی', 'شخص', 'مالکیت', 'رویداد_پیش\u200cزمینه', 'گوینده', 'رویداد_مقایسه', 'مقوله', 'مدت_زمان', 'محل', 'فعالیت', 'جریمه', 'بارش', 'مکان', 'مسافر', 'محل_اجرا', 'جستجو_کننده', 'کیفیت_نهایی', 'کنشگر', 'موجود', 'توصیف\u200cگر', 'محتوا', 'پیکر', 'حسگر', 'اهداکننده', 'موضوع', 'مالک', 'شیوه', 'هدف', 'مرجع_ذیصلاح', 'طرف_متأثر', 'مقصود', 'پیام', 'هدف_رویداد', 'درجه', 'رویداد_همزمان'}

# %%
df['frameNetTags'] = df['frameNetTags'].apply(lambda label : [frame2id[l] for l in label])
# Out:
# <ipython-input-28-b2dc9e216140>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['frameNetTags'] = df['frameNetTags'].apply(lambda label : [frame2id[l] for l in label])

# %%
df
# Out:
#                                                 words  \
# 0   خانم نزهت‌الدوله گرچه تا به حال سه تا شوهر کرد...
# 1   خانم نزهت‌الدوله گرچه تا به حال سه تا شوهر کرد...
# 2                  تو به من مجال دادی تا پروانه شوم .
# 3                  تو به من مجال دادی تا پروانه شوم .
# 4   هر زمان این غریزه و فطرت و رشد سنی و عقلی و اج...
# ..                                                ...
# 95  یکی از ضعف‌های اصلی در نمایش زایشی ، عدم توانا...
# 96  از نحوۀ نشستن ، ایستادن ، استفاده از دست‌ها و ...
# 97  سعی کنید چند نمونه از این حرکات را اتخاذ کرده ...
# 98  سعی کنید چند نمونه از این حرکات را اتخاذ کرده ...
# 99  پس از عادت کردن کامل به این چند حرکت ، چند رفت...
#
#                                          frameNetTags  \
# 0   [35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 3...
# 1   [72, 72, 35, 35, 35, 35, 35, 35, 35, 35, 35, 3...
# 2                [85, 15, 15, 35, 35, 45, 45, 45, 35]
# 3                [35, 35, 35, 35, 35, 35, 12, 35, 35]
# 4   [35, 35, 50, 50, 50, 50, 50, 50, 50, 50, 50, 5...
# ..                                                ...
# 95  [35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 2, 2,...
# 96  [35, 35, 35, 35, 35, 35, 35, 48, 48, 48, 48, 3...
# 97  [35, 35, 84, 84, 84, 84, 84, 84, 84, 84, 84, 8...
# 98  [35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 6...
# 99  [35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 3...
#
#                                          propBankTags  \
# 0   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 1   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 2         [B-A0, B-A2, O, B-NVE, B-V, B-PRP, O, O, O]
# 3                    [O, O, O, O, O, O, B-A2, B-V, O]
# 4   [O, O, O, B-A2, O, O, O, O, O, O, O, O, O, B-N...
# ..                                                ...
# 95  [O, O, O, O, O, O, O, O, O, B-N-V, B-A1, O, O,...
# 96  [O, O, O, O, O, O, B-N-V, B-A1, O, O, O, O, O,...
# 97  [B-NVE, B-V, O, O, O, O, O, O, O, O, O, O, O, ...
# 98  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-E...
# 99  [O, O, O, O, O, O, O, O, O, O, B-EXT, B-N-V, O...
#
#                                                 Words
# 0   [خانم, نزهت‌الدوله, گرچه, تا, به, حال, سه, تا,...
# 1   [خانم, نزهت‌الدوله, گرچه, تا, به, حال, سه, تا,...
# 2        [تو, به, من, مجال, دادی, تا, پروانه, شوم, .]
# 3        [تو, به, من, مجال, دادی, تا, پروانه, شوم, .]
# 4   [هر, زمان, این, غریزه, و, فطرت, و, رشد, سنی, و...
# ..                                                ...
# 95  [یکی, از, ضعف‌های, اصلی, در, نمایش, زایشی, ،, ...
# 96  [از, نحوۀ, نشستن, ،, ایستادن, ،, استفاده, از, ...
# 97  [سعی, کنید, چند, نمونه, از, این, حرکات, را, ات...
# 98  [سعی, کنید, چند, نمونه, از, این, حرکات, را, ات...
# 99  [پس, از, عادت, کردن, کامل, به, این, چند, حرکت,...
#
# [100 rows x 4 columns]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["Words"], truncation=True, padding=True, is_split_into_words=True)
    labels = []
    for i, label in enumerate(examples[f"frameNetTags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
from datasets import Dataset
dataset = Dataset.from_pandas(df)
tokenized_data = dataset.map(tokenize_and_align_labels, batched=True)
# Out:
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
tokenized_data = tokenized_data.train_test_split(test_size=0.3)

# %%
import evaluate
seqeval = evaluate.load("seqeval")
# Out:
# Downloading builder script:   0%|          | 0.00/6.34k [00:00<?, ?B/s]

# %%
accuracy = evaluate.load("accuracy")
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
from transformers import DataCollatorForTokenClassification
data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
from transformers import AutoModelForTokenClassification
model = AutoModelForTokenClassification.from_pretrained('bert-base-multilingual-uncased', num_labels=len(frame2id)+1,ignore_mismatched_sizes=True)
# Out:
# model.safetensors:   0%|          | 0.00/672M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import BertTokenizer,  BatchEncoding
from transformers import AutoTokenizer, ModernBertForTokenClassification
import torch
from tokenizers import Encoding
model = AutoModelForTokenClassification.from_pretrained('bert-base-multilingual-uncased', num_labels=len(frame2id)+1,ignore_mismatched_sizes=True)
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
label2id = dict(frame2id)

# %%
id2label = dict((v,k) for k,v in label2id.items())

# %%
label_list = list(frame2id.keys())
from sklearn.metrics import classification_report, precision_recall_fscore_support
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import classification_report
def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [id2label[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [id2label[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels_bin = list(np.concatenate(true_labels))
    pred_labels_bin = list(np.concatenate(true_predictions))
    print(true_labels_bin)
    print(pred_labels_bin)
    report = classification_report(true_labels_bin, pred_labels_bin)
    metrics = precision_recall_fscore_support(true_labels_bin, pred_labels_bin, average='weighted')
    accuracy = metrics[0]
    precision = metrics[1]
    recall = metrics[2]
    f1_score = metrics[3]
    return {
        "precision": precision,
        "recall": recall,
        "f1": f1_score,
        "accuracy": accuracy
    }

# %%
training_args = TrainingArguments(
    output_dir="bert-token-classification",
    learning_rate=0.1,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=1,
    evaluation_strategy="epoch",
    weight_decay=0.01,
    save_strategy="no",
    #use_cpu=True,
    #no_cuda=True,
    #load_best_model_at_end=True, # uncomment if you wanna save
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1594: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
trainer = Trainer(model=model,args=training_args,data_collator=data_collator,train_dataset=tokenized_data['train']  ,eval_dataset=tokenized_data['test'],compute_metrics=compute_metrics,)

# %%
trainer.train()

# %%
trainer.evaluate()
